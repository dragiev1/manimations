# %%
from manim import *

# %%
class MovingAround(Scene):
  def construct(self):
    square = Square(color = BLUE, fill_opacity = 1)

    self.play(square.animate.shift(LEFT))
    self.play(square.animate.set_fill(ORANGE), run_time = 0.5)
    self.play(square.animate.scale(0.3), run_time = 0.3)
    self.play(square.animate.rotate(0.4), run_time = 0.2)
    self.wait()

# %%
class MovingAngle(Scene):
  def construct(self):
    rotation_center = LEFT

    theta_tracker = ValueTracker(110)
    line1 = Line(LEFT, RIGHT)
    line_moving = line1.copy()
    line_ref = line_moving.copy()

    line_moving.rotate(
      theta_tracker.get_value() * DEGREES, about_point = rotation_center
    )

    a = Angle(line1, line_moving, radius = 0.5, other_angle = False)

    tex = MathTex(r"\theta").move_to(
      Angle(
        line1, line_moving, radius=0.5 + 3 * SMALL_BUFF, other_angle=False
      ).point_from_proportion(0.5)
    )

    self.add(line1, line_moving, a, tex)
    self.wait()

# %%
manim -pqm MovingAngle
# Out:
# Manim Community v0.20.0
# [02/26/26 16:13:37] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=56943;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=853281;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}\theta\special{dvisvgm:raw </g>} to
#                              media/Tex/0b9215251ae6c644.tex
#                     INFO     Animation 0 : Partial movie file written in                   ]8;id=442280;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=455728;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene_file_writer.py#590\590]8;;\
#                              '/home/dragi/Documents/manimations/code/media/videos/code/720
#                              p30/partial_movie_files/MovingAngle/1987512680_2688965532_204
#                              9068881.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=268504;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=213505;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene_file_writer.py#742\742]8;;\
#                     INFO                                                                   ]8;id=518391;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=152118;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene_file_writer.py#893\893]8;;\
#                              File ready at
#                              '/home/dragi/Documents/manimations/code/media/videos/code/720
#                              p30/MovingAngle.mp4'
#                     INFO     Rendered MovingAngle                                                      ]8;id=1598;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=933732;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene.py#278\278]8;;\
#                              Played 1 animations
# [02/26/26 16:13:38] INFO     Previewed File at:                                                     ]8;id=756756;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/utils/file_ops.py\file_ops.py]8;;\:]8;id=656683;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/utils/file_ops.py#236\236]8;;\
#                              '/home/dragi/Documents/manimations/code/media/videos/code/720p30/Movin
#                              gAngle.mp4'
# <video src="media/jupyter/MovingAngle@2026-02-26@16-13-38.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
