# %%
from manim import *

# %%
class MovingAround(Scene):
  def construct(self):
    square = Square(color = BLUE, fill_opacity = 1)

    self.play(square.animate.shift(LEFT))
    self.play(square.animate.set_fill(ORANGE), run_time = 0.5)
    self.play(square.animate.scale(0.3), run_time = 0.3)
    self.play(square.animate.rotate(0.4), run_time = 0.2)
    self.wait()

# %%
class MovingAngle(Scene):
  def construct(self):
    rotation_center = LEFT

    theta_tracker = ValueTracker(110)
    line1 = Line(LEFT, RIGHT)
    line_moving = line1.copy()
    line_ref = line_moving.copy()

    line_moving.rotate(
      theta_tracker.get_value() * DEGREES, about_point = rotation_center
    )

    a = Angle(line1, line_moving, radius = 0.5, other_angle = False)

    tex = MathTex(r"\theta").move_to(
      Angle(
        line1, line_moving, radius=0.5 + 3 * SMALL_BUFF, other_angle=False
      ).point_from_proportion(0.5)
    )

    self.add(line1, line_moving, a, tex)
    self.wait()

    line_moving.add_updater(
      lambda x: x.become(line_ref.copy()).rotate(
        theta_tracker.get_value() * DEGREES, about_point=rotation_center
      )
    )

    a.add_updater(
      lambda x: x.become(Angle(line1, line_moving, radius=0.5, other_angle=False))
    )

    tex.add_updater(
      lambda x: x.move_to(
        Angle(
          line1, line_moving, radius=0.5 + 3 * SMALL_BUFF, other_angle=False
        ).point_from_proportion(0.5)
      )
    )

    self.play(theta_tracker.animate.set_value(40))
    self.play(theta_tracker.animate.increment_value(140))
    self.play(tex.animate.set_color(RED), run_time=0.5)
    self.play(theta_tracker.animate.set_value(350))
    self.wait()

# %%
manim -pqm MovingAngle
# Out:
# Manim Community v0.20.0
# [02/26/26 17:28:23] INFO     Animation 0 : Using cached data (hash :                           ]8;id=129982;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=462853;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py#94\94]8;;\
#                              1987512680_2688965532_3311565046)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=413202;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=913713;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py#94\94]8;;\
#                              2538612922_1189483133_996762577)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=725801;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=395464;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py#94\94]8;;\
#                              2538612922_2981851736_1115658972)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=310552;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=811995;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py#94\94]8;;\
#                              2538612922_1008864003_3778441760)
#                     INFO     Animation 4 : Using cached data (hash :                           ]8;id=139718;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=444906;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py#94\94]8;;\
#                              2538612922_696273257_2515853379)
#                     INFO     Animation 5 : Using cached data (hash :                           ]8;id=919744;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=712746;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/renderer/cairo_renderer.py#94\94]8;;\
#                              2538612922_2688965532_4259996214)
#                     INFO     Combining to Movie file.                                      ]8;id=831176;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=309555;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene_file_writer.py#742\742]8;;\
#                     INFO                                                                   ]8;id=477100;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=487961;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene_file_writer.py#893\893]8;;\
#                              File ready at
#                              '/home/dragi/Documents/manimations/code/media/videos/code/720
#                              p30/MovingAngle.mp4'
#                     INFO     Rendered MovingAngle                                                      ]8;id=854627;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=239230;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/scene/scene.py#278\278]8;;\
#                              Played 6 animations
# [02/26/26 17:28:24] INFO     Previewed File at:                                                     ]8;id=404425;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/utils/file_ops.py\file_ops.py]8;;\:]8;id=928915;file:///home/dragi/Documents/manimations/.venv/lib/python3.14/site-packages/manim/utils/file_ops.py#236\236]8;;\
#                              '/home/dragi/Documents/manimations/code/media/videos/code/720p30/Movin
#                              gAngle.mp4'
# <video src="media/jupyter/MovingAngle@2026-02-26@17-28-24.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
